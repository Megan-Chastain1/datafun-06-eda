# %% [markdown]
# # Global Health Spending
#
# - Author: [Megan Chastain](https://github.com/Megan-Chastain1)
# - Repository: [datafun-6-eda](https://github.com/Megan-Chastain1/datafun-6-eda)
# - Date: 10/3/2025

# %% [markdown]
# # Introduction
#     My name is Megan Chastain and in this project I explore the Seaborn dataset, Health Expenditure. In this dataset, we can see data collected from different countries and years that shows how life expectancy can change over years. The dataset also incluedes the average amount spent on health.

# %% [markdown]
# ![heatlthexp.jpg](attachment:5e48a3ad-0f65-4598-aa7e-0fe11734b197.jpg)

# %% [markdown]
# # Import External Packages and Load Dataset

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib
import ipywidgets  
import IPython  
import jupyterlab
from matplotlib.axes import Axes

health_expenditure_df: pd.DataFrame = sns.load_dataset("healthexp")
health_expenditure_df.head()
# Out:
#    Year        Country  Spending_USD  Life_Expectancy
# 0  1970        Germany       252.311             70.6
# 1  1970         France       192.143             72.2
# 2  1970  Great Britain       123.993             71.9
# 3  1970          Japan       150.437             72.0
# 4  1970            USA       326.961             70.9

# %% [markdown]
# # Initial Exploration of the Dataset

# %%
# Display column information along with shape of the data
health_expenditure_df.head(20)

health_expenditure_df.shape

health_expenditure_df.dtypes

health_expenditure_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 274 entries, 0 to 273
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Year             274 non-null    int64
#  1   Country          274 non-null    object
#  2   Spending_USD     274 non-null    float64
#  3   Life_Expectancy  274 non-null    float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 8.7+ KB

# %%
health_expenditure_df['Country'].value_counts()

# Inspect value counts for ALL categorical columns
for col in health_expenditure_df.select_dtypes(include=['object', 'category']).columns:
    # Display count plot
    sns.countplot(x=col, data=health_expenditure_df)
    matplotlib.pyplot.title(f'Distribution of {col}')
    matplotlib.pyplot.show()

# Show all plots
matplotlib.pyplot.show()

# %%
# Inspect summary statistics for numerical columns
health_expenditure_df.describe()
# Out:
#               Year  Spending_USD  Life_Expectancy
# count   274.000000    274.000000       274.000000
# mean   1996.992701   2789.338905        77.909489
# std      14.180933   2194.939785         3.276263
# min    1970.000000    123.993000        70.600000
# 25%    1985.250000   1038.357000        75.525000
# 50%    1998.000000   2295.578000        78.100000
# 75%    2009.000000   4055.610000        80.575000
# max    2020.000000  11859.179000        84.700000

# %% [markdown]
# # Visualize the Data

# %%
# Create a scatter plot of health spending vs life expectancy
scatter_plt: Axes = sns.scatterplot(
    data=health_expenditure_df, x="Life_Expectancy", y="Spending_USD", hue="Country"
)

# Set axis labels using the Matplotlib Axes methods set_xlabel() and set_ylabel()
scatter_plt.set_xlabel("Life Expectancy")
scatter_plt.set_ylabel("Spending (USD)")

# Set the title using the Matplotlib Axes set_title() method
scatter_plt.set_title("Chart 1. Life Expectancy vs. Spending(USD)")
# Out:
# Text(0.5, 1.0, 'Chart 1. Life Expectancy vs. Spending(USD)')

# %% [markdown]
# # Conclusions

# %% [markdown]
# Based on the scatterplot, Japan spends the least amount on the health while having the longest life expectancy.
